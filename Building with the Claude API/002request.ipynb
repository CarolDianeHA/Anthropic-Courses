# %%
# Load env variables

from dotenv import load_dotenv
load_dotenv()

# Create an API client

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }

    if system:
        params["system"] = system

    # system = """ 
    # You are a patient math tutor.
    # Do not directly answer a student's questions.
    # Guide them to a solution step by step.
    # """
    message = client.messages.create(
        **params
    )
    return message.content[0].text

# %%
messages = []

system = """ 
    You are a patient math tutor.
    Do not directly answer a student's questions.
    Guide them to a solution step by step.
    """

add_user_message(messages, "How do I solve 5x+3=2 for x?")
response = chat(messages, system=system)
print(response)

# %%
messages = []

add_user_message(messages, "Write a Python function that checks a string for duplicate characters.")
response = chat(messages, system="Your are a Python engineer who writes very concise code.")
print(response)
# Out:
# Here's a concise Python function that checks for duplicate characters in a string:
#
# ```python
# def has_duplicates(s):
#     return len(s) != len(set(s))
# ```
#
# **Examples:**
# ```python
# print(has_duplicates("hello"))   # True  ('l' appears twice)
# print(has_duplicates("world"))   # False (all unique)
# print(has_duplicates("python"))  # False (all unique)
# print(has_duplicates("abcabc"))  # True  (a, b, c repeat)
# ```
#
# If you also want to **identify which characters are duplicates**:
#
# ```python
# def find_duplicates(s):
#     return {char for char in s if s.count(char) > 1}
# ```
#
# **Examples:**
# ```python
# print(find_duplicates("hello"))   # {'l'}
# print(find_duplicates("abcabc"))  # {'a', 'b', 'c'}
# print(find_duplicates("python"))  # set() (empty = no duplicates)
# ```
#
# Or using `collections.Counter` for **duplicate counts**:
#
# ```python
# from collections import Counter
#
# def duplicate_counts(s):
#     return {char: count for char, count in Counter(s).items() if count > 1}
# ```
#
# **Examples:**
# ```python
# print(duplicate_counts("hello world"))  # {'l': 3, 'o': 2, ' ': 1} ...
# print(duplicate_counts("aabbcc"))       # {'a': 2, 'b': 2, 'c': 2}
# print(duplicate_counts("python"))       # {} (no duplicates)
# ```
#
# | Function | Use Case |
# |---|---|
# | `has_duplicates` | Quick True/False check |
# | `find_duplicates` | Get the duplicate characters |
# | `duplicate_counts` | Get characters with their counts |
