# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.5

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\n\ndef parse_s3_bucket(uri):\n    match = re.match(r's3://([a-z0-9.-]+)/', uri)\n    return match.group(1) if match else None\n",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI (e.g., 's3://my-bucket-name/path/to/file.txt') and extract just the bucket name",
#       "format": "regex",
#       "solution_criteria": "The regex should correctly extract bucket names from various S3 URI formats, handling bucket names with hyphens and numbers, and should not match invalid characters or the path portion"
#     },
#     "score": 8.0,
#     "reasoning": "The solution works for common cases with well-formed URIs containing paths, but has limitations with edge cases and missing validation. The regex character class is too restrictive for real-world usage, and bucket-only URIs without paths will not match. While basic functionality is sound, the solution lacks robustness for production use."
#   },
#   {
#     "output": "\n{\n  \"Handler\": \"index.handler\",\n  \"Timeout\": 300,\n  \"MemorySize\": 512,\n  \"Environment\": {\n    \"Variables\": {}\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that specifies environment variables, timeout (300 seconds), memory size (512 MB), and a handler pointing to 'index.handler'",
#       "format": "json",
#       "solution_criteria": "The JSON should be valid, properly structured with all required fields, use correct key names matching AWS Lambda configuration standards, and have realistic values"
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly implements the core requirements with proper JSON syntax and accurate AWS Lambda API field names. However, it treats the Environment Variables as a placeholder rather than including meaningful examples, and omits supplementary configuration that would be necessary for a production-ready Lambda function. The configuration is technically correct but incomplete for real-world usage."
#   },
#   {
#     "output": "\nimport re\n\ndef validate_aws_instance_id(instance_id: str) -> bool:\n    \"\"\"\n    Validates whether a string matches the proper AWS EC2 instance ID format.\n    \n    AWS EC2 instance IDs follow the pattern:\n    - Start with 'i-'\n    - Followed by 17 hexadecimal characters (0-9, a-f)\n    \n    Args:\n        instance_id: The instance ID string to validate\n        \n    Returns:\n        True if the instance ID matches the proper format, False otherwise\n    \"\"\"\n    pattern = r'^i-[0-9a-f]{17}$'\n    return bool(re.match(pattern, instance_id))\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        ('i-0123456789abcdef0', True),\n        ('i-1234567890abcdef0', True),\n        ('i-ffffffffffffffff0', True),\n        ('i-0000000000000000', True),\n        ('i-012345678', False),\n        ('i-0123456789abcdef', False),\n        ('i-0123456789abcdef00', False),\n        ('I-0123456789abcdef0', False),\n        ('0123456789abcdef0', False),\n        ('i-0123456789abcdefG', False),\n        ('', False),\n    ]\n    \n    for instance_id, expected in test_cases:\n        result = validate_aws_instance_id(instance_id)\n        status = \"\u2713\" if result == expected else \"\u2717\"\n        print(f\"{status} {instance_id}: {result} (expected {expected})\")\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS EC2 instance ID string (e.g., 'i-0123456789abcdef0') and validates whether it matches the proper AWS instance ID format",
#       "format": "python",
#       "solution_criteria": "The function should return True for valid instance IDs and False for invalid ones, handle edge cases like empty strings, and follow AWS instance ID naming conventions (i- prefix followed by 17 hexadecimal characters)"
#     },
#     "score": 9.0,
#     "reasoning": "The solution correctly validates AWS EC2 instance ID format and passes all provided test cases. The regex pattern is accurate and the documentation is clear. However, there are minor robustness issues: the function lacks type checking for non-string inputs, which could cause unexpected runtime errors rather than returning False. Adding a simple isinstance check would make this production-ready. The solution appropriately focuses on format validation rather than actual AWS API calls, which is the correct approach."
#   }
# ]
